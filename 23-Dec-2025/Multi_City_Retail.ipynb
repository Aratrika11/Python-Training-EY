# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window

spark=SparkSession.builder.appName("Capstone_Demo").getOrCreate()

# %% [markdown]
# #PHASE 1 — DATA INGESTION & SCHEMA MANAGEMENT
# Tasks
#
# 1. Create schemas explicitly for all datasets
# 2. Load raw data into DataFrames
# 3. Handle incorrect data types gracefully
# 4. Identify corrupt and invalid records

# %% [markdown]
# DATASET 1 — SALES TRANSACTIONS (CSV)

# %%
sales_data = [
    ("TXN001","Delhi ","Laptop","Electronics","45000","2024-01-05","Completed"),
    ("TXN002","Mumbai","Mobile ","electronics","32000","05/01/2024","Completed"),
    ("TXN003","Bangalore","Tablet"," Electronics ","30000","2024/01/06","Completed"),
    ("TXN004","Delhi","Laptop","Electronics","","2024-01-07","Cancelled"),
    ("TXN005","Chennai","Mobile","Electronics","invalid","2024-01-08","Completed"),
    ("TXN006","Mumbai","Tablet","Electronics",None,"2024-01-08","Completed"),
    ("TXN007","Delhi","Laptop","electronics","45000","09-01-2024","Completed"),
    ("TXN008","Bangalore","Mobile","Electronics","28000","2024-01-09","Completed"),
    ("TXN009","Mumbai","Laptop","Electronics","55000","2024-01-10","Completed"),
    ("TXN009","Mumbai","Laptop","Electronics","55000","2024-01-10","Completed")
]
sales_schema=StructType([
    StructField("txn_id",StringType(),True),
    StructField("city",StringType(),True),
    StructField("product",StringType(),True),
    StructField("category",StringType(),True),
    StructField("amount",StringType(),True),
    StructField("txn_date",StringType(),True),
    StructField("status",StringType(),True)
])
sales_df=spark.createDataFrame(sales_data,sales_schema)
sales_df.show()
# Out:
# +------+---------+-------+-------------+-------+----------+---------+
# |txn_id|     city|product|     category| amount|  txn_date|   status|
# +------+---------+-------+-------------+-------+----------+---------+
# |TXN001|   Delhi | Laptop|  Electronics|  45000|2024-01-05|Completed|
# |TXN002|   Mumbai|Mobile |  electronics|  32000|05/01/2024|Completed|
# |TXN003|Bangalore| Tablet| Electronics |  30000|2024/01/06|Completed|
# |TXN004|    Delhi| Laptop|  Electronics|       |2024-01-07|Cancelled|
# |TXN005|  Chennai| Mobile|  Electronics|invalid|2024-01-08|Completed|
# |TXN006|   Mumbai| Tablet|  Electronics|   NULL|2024-01-08|Completed|
# |TXN007|    Delhi| Laptop|  electronics|  45000|09-01-2024|Completed|
# |TXN008|Bangalore| Mobile|  Electronics|  28000|2024-01-09|Completed|
# |TXN009|   Mumbai| Laptop|  Electronics|  55000|2024-01-10|Completed|
# |TXN009|   Mumbai| Laptop|  Electronics|  55000|2024-01-10|Completed|
# +------+---------+-------+-------------+-------+----------+---------+

# %% [markdown]
# DATASET 2 — CUSTOMER MASTER

# %%
customer_data = [
("C001","Delhi","Premium"),
("C002","Mumbai","Standard"),
("C003","Bangalore","Premium"),
("C004","Chennai","Standard"),
("C005","Mumbai","Premium")
]
customer_schema=StructType([
    StructField("customer_id",StringType(),True),
    StructField("city",StringType(),True),
    StructField("segment",StringType(),True)
])
customer_df=spark.createDataFrame(customer_data,customer_schema)
customer_df.show()
# Out:
# +-----------+---------+--------+
# |customer_id|     city| segment|
# +-----------+---------+--------+
# |       C001|    Delhi| Premium|
# |       C002|   Mumbai|Standard|
# |       C003|Bangalore| Premium|
# |       C004|  Chennai|Standard|
# |       C005|   Mumbai| Premium|
# +-----------+---------+--------+

# %% [markdown]
# DATASET 3 — CITY CLASSIFICATION

# %%
city_data = [
("Delhi","Tier-1"),
("Mumbai","Tier-1"),
("Bangalore","Tier-1"),
("Chennai","Tier-2")
]
city_schema=StructType([
    StructField("city",StringType(),True),
    StructField("tier",StringType(),True)
])
city_df=spark.createDataFrame(city_data,city_schema)
city_df.show()
# Out:
# +---------+------+
# |     city|  tier|
# +---------+------+
# |    Delhi|Tier-1|
# |   Mumbai|Tier-1|
# |Bangalore|Tier-1|
# |  Chennai|Tier-2|
# +---------+------+

# %%
sales_df.filter(col("amount").isNull() | ~col("amount").rlike(r'^[0-9]+$')).show()
# Out:
# +------+-------+-------+-----------+-------+----------+---------+
# |txn_id|   city|product|   category| amount|  txn_date|   status|
# +------+-------+-------+-----------+-------+----------+---------+
# |TXN004|  Delhi| Laptop|Electronics|       |2024-01-07|Cancelled|
# |TXN005|Chennai| Mobile|Electronics|invalid|2024-01-08|Completed|
# |TXN006| Mumbai| Tablet|Electronics|   NULL|2024-01-08|Completed|
# +------+-------+-------+-----------+-------+----------+---------+

# %% [markdown]
# PHASE 2 — DATA CLEANING &
# TRANSFORMATION
#
# Tasks
#
# 5. Trim and normalize string columns
# 6. Convert category to uppercase
# 7. Convert amount to integer
# 8. Handle invalid and null amounts
# 9. Parse multiple date formats into DateType
# 10. Remove duplicate transactions
# 11. Keep only Completed transactions

# %%
#5
clean_df=sales_df.withColumn("city",trim(col("city")))\
.withColumn("product",trim(col("product")))\
.withColumn("category",trim(col("category")))\
.withColumn("status",trim(col("status")))

clean_df.show()
# Out:
# +------+---------+-------+-----------+-------+----------+---------+
# |txn_id|     city|product|   category| amount|  txn_date|   status|
# +------+---------+-------+-----------+-------+----------+---------+
# |TXN001|    Delhi| Laptop|Electronics|  45000|2024-01-05|Completed|
# |TXN002|   Mumbai| Mobile|electronics|  32000|05/01/2024|Completed|
# |TXN003|Bangalore| Tablet|Electronics|  30000|2024/01/06|Completed|
# |TXN004|    Delhi| Laptop|Electronics|       |2024-01-07|Cancelled|
# |TXN005|  Chennai| Mobile|Electronics|invalid|2024-01-08|Completed|
# |TXN006|   Mumbai| Tablet|Electronics|   NULL|2024-01-08|Completed|
# |TXN007|    Delhi| Laptop|electronics|  45000|09-01-2024|Completed|
# |TXN008|Bangalore| Mobile|Electronics|  28000|2024-01-09|Completed|
# |TXN009|   Mumbai| Laptop|Electronics|  55000|2024-01-10|Completed|
# |TXN009|   Mumbai| Laptop|Electronics|  55000|2024-01-10|Completed|
# +------+---------+-------+-----------+-------+----------+---------+

# %%
#6
clean_df=clean_df.withColumn("category",upper(col("category")))
#clean_df.show()

#7
clean_df=clean_df.withColumn("amount_int",when(col("amount").rlike("^[0-9]+$"),col("amount").cast(IntegerType())))
#clean_df.show()

#8
clean_df=clean_df.filter(col("amount_int").isNotNull())
#clean_df.show()

#9
clean_df=clean_df.withColumn("txn_date_parsed",coalesce(
                             try_to_timestamp(col("txn_date"), lit("yyyy-MM-dd")),
                             try_to_timestamp(col("txn_date"), lit("dd-MM-yyyy")),
                             try_to_timestamp(col("txn_date"), lit("MM-dd-yyyy")),
                             try_to_timestamp(col("txn_date"), lit("dd/MM/yyyy")),
                             try_to_timestamp(col("txn_date"), lit("MM/dd/yyyy")),
                             try_to_timestamp(col("txn_date"), lit("yyyy/MM/dd"))
                                                          ).cast(DateType()))
#clean_df.show()

#10
clean_df=clean_df.dropDuplicates()
#clean_df.show()


#11
clean_df=clean_df.filter(col("status").like("Comple%"))
clean_df.show()
# Out:
# +------+---------+-------+-----------+------+----------+---------+----------+---------------+
# |txn_id|     city|product|   category|amount|  txn_date|   status|amount_int|txn_date_parsed|
# +------+---------+-------+-----------+------+----------+---------+----------+---------------+
# |TXN003|Bangalore| Tablet|ELECTRONICS| 30000|2024/01/06|Completed|     30000|     2024-01-06|
# |TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|05/01/2024|Completed|     32000|     2024-01-05|
# |TXN001|    Delhi| Laptop|ELECTRONICS| 45000|2024-01-05|Completed|     45000|     2024-01-05|
# |TXN007|    Delhi| Laptop|ELECTRONICS| 45000|09-01-2024|Completed|     45000|     2024-01-09|
# |TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|2024-01-10|Completed|     55000|     2024-01-10|
# |TXN008|Bangalore| Mobile|ELECTRONICS| 28000|2024-01-09|Completed|     28000|     2024-01-09|
# +------+---------+-------+-----------+------+----------+---------+----------+---------------+
#
# +------+---------+-------+-----------+------+----------+---------+----------+---------------+
# |txn_id|     city|product|   category|amount|  txn_date|   status|amount_int|txn_date_parsed|
# +------+---------+-------+-----------+------+----------+---------+----------+---------------+
# |TXN003|Bangalore| Tablet|ELECTRONICS| 30000|2024/01/06|Completed|     30000|     2024-01-06|
# |TXN002|   Mumbai| Mobile|ELECTRONICS| 32000|05/01/2024|Completed|     32000|     2024-01-05|
# |TXN001|    Delhi| Laptop|ELECTRONICS| 45000|2024-01-05|Completed|     45000|     2024-01-05|
# |TXN007|    Delhi| Laptop|ELECTRONICS| 45000|09-01-2024|Completed|     45000|     2024-01-09|
# |TXN009|   Mumbai| Laptop|ELECTRONICS| 55000|2024-01-10|Completed|     55000|     2024-01-10|
# |TXN008|Bangalore| Mobile|ELECTRONICS| 28000|2024-01-09|Completed|     28000|     2024-01-09|
# +------+---------+-------+-----------+------+----------+---------+----------+---------------+

# %% [markdown]
# PHASE 3 — DATA ENRICHMENT & JOINS
#
# Tasks
#
# 12. Join sales data with city lookup
# 13. Use broadcast join where appropriate
# 14. Explain join strategy used
# 15. Enrich sales data with city tier

# %%
#12,13
enriched_df=clean_df.join(broadcast(city_df),on="city",how="left")
enriched_df.show()
# Out:
# +---------+------+-------+-----------+------+----------+---------+----------+---------------+------+
# |     city|txn_id|product|   category|amount|  txn_date|   status|amount_int|txn_date_parsed|  tier|
# +---------+------+-------+-----------+------+----------+---------+----------+---------------+------+
# |Bangalore|TXN003| Tablet|ELECTRONICS| 30000|2024/01/06|Completed|     30000|     2024-01-06|Tier-1|
# |   Mumbai|TXN002| Mobile|ELECTRONICS| 32000|05/01/2024|Completed|     32000|     2024-01-05|Tier-1|
# |    Delhi|TXN001| Laptop|ELECTRONICS| 45000|2024-01-05|Completed|     45000|     2024-01-05|Tier-1|
# |    Delhi|TXN007| Laptop|ELECTRONICS| 45000|09-01-2024|Completed|     45000|     2024-01-09|Tier-1|
# |   Mumbai|TXN009| Laptop|ELECTRONICS| 55000|2024-01-10|Completed|     55000|     2024-01-10|Tier-1|
# |Bangalore|TXN008| Mobile|ELECTRONICS| 28000|2024-01-09|Completed|     28000|     2024-01-09|Tier-1|
# +---------+------+-------+-----------+------+----------+---------+----------+---------------+------+

# %%
#14
enriched_df.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Join UsingJoin(LeftOuter, [city])
# :- Filter status#76 LIKE Comple%
# :  +- Deduplicate [city#73, amount_int#261, amount#4, status#76, txn_date_parsed#262, txn_id#0, product#74, txn_date#5, category#260]
# :     +- Project [txn_id#0, city#73, product#74, category#260, amount#4, txn_date#5, status#76, amount_int#261, cast(coalesce(try_to_timestamp(txn_date#5, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd-MM-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM-dd-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM/dd/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) as date) AS txn_date_parsed#262]
# :        +- Filter isnotnull(amount_int#261)
# :           +- Project [txn_id#0, city#73, product#74, category#260, amount#4, txn_date#5, status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#261, txn_date_parsed#231]
# :              +- Project [txn_id#0, city#73, product#74, upper(category#229) AS category#260, amount#4, txn_date#5, status#76, amount_int#230, txn_date_parsed#231]
# :                 +- Filter status#76 LIKE Comple%
# :                    +- Project [txn_id#0, city#73, product#74, category#229, amount#4, txn_date#5, status#76, amount_int#230, cast(coalesce(try_to_timestamp(txn_date#5, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd-MM-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM-dd-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM/dd/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) as date) AS txn_date_parsed#231]
# :                       +- Filter isnotnull(amount_int#230)
# :                          +- Project [txn_id#0, city#73, product#74, category#229, amount#4, txn_date#5, status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#230, txn_date_parsed#200]
# :                             +- Project [txn_id#0, city#73, product#74, upper(category#198) AS category#229, amount#4, txn_date#5, status#76, amount_int#199, txn_date_parsed#200]
# :                                +- Project [txn_id#0, city#73, product#74, category#198, amount#4, txn_date#5, status#76, amount_int#199, cast(coalesce(try_to_timestamp(txn_date#5, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd-MM-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM-dd-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM/dd/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) as date) AS txn_date_parsed#200]
# :                                   +- Filter isnotnull(amount_int#199)
# :                                      +- Project [txn_id#0, city#73, product#74, category#198, amount#4, txn_date#5, status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#199]
# :                                         +- Project [txn_id#0, city#73, product#74, upper(category#171) AS category#198, amount#4, txn_date#5, status#76, amount_int#172]
# :                                            +- Filter isnotnull(amount_int#172)
# :                                               +- Project [txn_id#0, city#73, product#74, category#171, amount#4, txn_date#5, status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#172]
# :                                                  +- Project [txn_id#0, city#73, product#74, upper(category#122) AS category#171, amount#4, txn_date#5, status#76, amount_int#145]
# :                                                     +- Project [txn_id#0, city#73, product#74, category#122, amount#4, txn_date#5, status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#145]
# :                                                        +- Project [txn_id#0, city#73, product#74, upper(category#99) AS category#122, amount#4, txn_date#5, status#76]
# :                                                           +- Project [txn_id#0, city#73, product#74, upper(category#75) AS category#99, amount#4, txn_date#5, status#76]
# :                                                              +- Project [txn_id#0, city#73, product#74, category#75, amount#4, txn_date#5, trim(status#6, None) AS status#76]
# :                                                                 +- Project [txn_id#0, city#73, product#74, trim(category#3, None) AS category#75, amount#4, txn_date#5, status#6]
# :                                                                    +- Project [txn_id#0, city#73, trim(product#2, None) AS product#74, category#3, amount#4, txn_date#5, status#6]
# :                                                                       +- Project [txn_id#0, trim(city#1, None) AS city#73, product#2, category#3, amount#4, txn_date#5, status#6]
# :                                                                          +- LogicalRDD [txn_id#0, city#1, product#2, category#3, amount#4, txn_date#5, status#6], false
# +- ResolvedHint (strategy=broadcast)
#    +- LogicalRDD [city#42, tier#43], false
#
# == Analyzed Logical Plan ==
# city: string, txn_id: string, product: string, category: string, amount: string, txn_date: string, status: string, amount_int: int, txn_date_parsed: date, tier: string
# Project [city#73, txn_id#0, product#74, category#260, amount#4, txn_date#5, status#76, amount_int#261, txn_date_parsed#262, tier#43]
# +- Join LeftOuter, (city#73 = city#42)
#    :- Filter status#76 LIKE Comple%
#    :  +- Deduplicate [city#73, amount_int#261, amount#4, status#76, txn_date_parsed#262, txn_id#0, product#74, txn_date#5, category#260]
#    :     +- Project [txn_id#0, city#73, product#74, category#260, amount#4, txn_date#5, status#76, amount_int#261, cast(coalesce(try_to_timestamp(txn_date#5, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd-MM-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM-dd-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM/dd/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) as date) AS txn_date_parsed#262]
#    :        +- Filter isnotnull(amount_int#261)
#    :           +- Project [txn_id#0, city#73, product#74, category#260, amount#4, txn_date#5, status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#261, txn_date_parsed#231]
#    :              +- Project [txn_id#0, city#73, product#74, upper(category#229) AS category#260, amount#4, txn_date#5, status#76, amount_int#230, txn_date_parsed#231]
#    :                 +- Filter status#76 LIKE Comple%
#    :                    +- Project [txn_id#0, city#73, product#74, category#229, amount#4, txn_date#5, status#76, amount_int#230, cast(coalesce(try_to_timestamp(txn_date#5, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd-MM-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM-dd-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM/dd/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) as date) AS txn_date_parsed#231]
#    :                       +- Filter isnotnull(amount_int#230)
#    :                          +- Project [txn_id#0, city#73, product#74, category#229, amount#4, txn_date#5, status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#230, txn_date_parsed#200]
#    :                             +- Project [txn_id#0, city#73, product#74, upper(category#198) AS category#229, amount#4, txn_date#5, status#76, amount_int#199, txn_date_parsed#200]
#    :                                +- Project [txn_id#0, city#73, product#74, category#198, amount#4, txn_date#5, status#76, amount_int#199, cast(coalesce(try_to_timestamp(txn_date#5, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd-MM-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM-dd-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(MM/dd/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(txn_date#5, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) as date) AS txn_date_parsed#200]
#    :                                   +- Filter isnotnull(amount_int#199)
#    :                                      +- Project [txn_id#0, city#73, product#74, category#198, amount#4, txn_date#5, status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#199]
#    :                                         +- Project [txn_id#0, city#73, product#74, upper(category#171) AS category#198, amount#4, txn_date#5, status#76, amount_int#172]
#    :                                            +- Filter isnotnull(amount_int#172)
#    :                                               +- Project [txn_id#0, city#73, product#74, category#171, amount#4, txn_date#5, status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#172]
#    :                                                  +- Project [txn_id#0, city#73, product#74, upper(category#122) AS category#171, amount#4, txn_date#5, status#76, amount_int#145]
#    :                                                     +- Project [txn_id#0, city#73, product#74, category#122, amount#4, txn_date#5, status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#145]
#    :                                                        +- Project [txn_id#0, city#73, product#74, upper(category#99) AS category#122, amount#4, txn_date#5, status#76]
#    :                                                           +- Project [txn_id#0, city#73, product#74, upper(category#75) AS category#99, amount#4, txn_date#5, status#76]
#    :                                                              +- Project [txn_id#0, city#73, product#74, category#75, amount#4, txn_date#5, trim(status#6, None) AS status#76]
#    :                                                                 +- Project [txn_id#0, city#73, product#74, trim(category#3, None) AS category#75, amount#4, txn_date#5, status#6]
#    :                                                                    +- Project [txn_id#0, city#73, trim(product#2, None) AS product#74, category#3, amount#4, txn_date#5, status#6]
#    :                                                                       +- Project [txn_id#0, trim(city#1, None) AS city#73, product#2, category#3, amount#4, txn_date#5, status#6]
#    :                                                                          +- LogicalRDD [txn_id#0, city#1, product#2, category#3, amount#4, txn_date#5, status#6], false
#    +- ResolvedHint (strategy=broadcast)
#       +- LogicalRDD [city#42, tier#43], false
#
# == Optimized Logical Plan ==
# Project [city#73, txn_id#0, product#74, category#260, amount#4, txn_date#5, status#76, amount_int#261, txn_date_parsed#262, tier#43]
# +- Join LeftOuter, (city#73 = city#42), rightHint=(strategy=broadcast)
#    :- Aggregate [city#73, amount_int#261, amount#4, status#76, txn_date_parsed#262, txn_id#0, product#74, txn_date#5, category#260], [txn_id#0, city#73, product#74, category#260, amount#4, txn_date#5, status#76, amount_int#261, txn_date_parsed#262]
#    :  +- Project [txn_id#0, trim(city#1, None) AS city#73, trim(product#2, None) AS product#74, upper(trim(category#3, None)) AS category#260, amount#4, txn_date#5, trim(status#6, None) AS status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#261, cast(coalesce(gettimestamp(txn_date#5, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(txn_date#5, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(txn_date#5, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(txn_date#5, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(txn_date#5, MM/dd/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(txn_date#5, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) as date) AS txn_date_parsed#262]
#    :     +- Filter (CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN isnotnull(cast(amount#4 as int)) ELSE false END AND StartsWith(trim(status#6, None), Comple))
#    :        +- LogicalRDD [txn_id#0, city#1, product#2, category#3, amount#4, txn_date#5, status#6], false
#    +- Filter isnotnull(city#42)
#       +- LogicalRDD [city#42, tier#43], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [city#73, txn_id#0, product#74, category#260, amount#4, txn_date#5, status#76, amount_int#261, txn_date_parsed#262, tier#43]
#    +- BroadcastHashJoin [city#73], [city#42], LeftOuter, BuildRight, false
#       :- HashAggregate(keys=[city#73, amount_int#261, amount#4, status#76, txn_date_parsed#262, txn_id#0, product#74, txn_date#5, category#260], functions=[], output=[txn_id#0, city#73, product#74, category#260, amount#4, txn_date#5, status#76, amount_int#261, txn_date_parsed#262])
#       :  +- Exchange hashpartitioning(city#73, amount_int#261, amount#4, status#76, txn_date_parsed#262, txn_id#0, product#74, txn_date#5, category#260, 200), ENSURE_REQUIREMENTS, [plan_id=439]
#       :     +- HashAggregate(keys=[city#73, amount_int#261, amount#4, status#76, txn_date_parsed#262, txn_id#0, product#74, txn_date#5, category#260], functions=[], output=[city#73, amount_int#261, amount#4, status#76, txn_date_parsed#262, txn_id#0, product#74, txn_date#5, category#260])
#       :        +- Project [txn_id#0, trim(city#1, None) AS city#73, trim(product#2, None) AS product#74, upper(trim(category#3, None)) AS category#260, amount#4, txn_date#5, trim(status#6, None) AS status#76, CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN cast(amount#4 as int) END AS amount_int#261, cast(coalesce(gettimestamp(txn_date#5, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(txn_date#5, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(txn_date#5, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(txn_date#5, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(txn_date#5, MM/dd/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(txn_date#5, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) as date) AS txn_date_parsed#262]
#       :           +- Filter (CASE WHEN RLIKE(amount#4, ^[0-9]+$) THEN isnotnull(cast(amount#4 as int)) ELSE false END AND StartsWith(trim(status#6, None), Comple))
#       :              +- Scan ExistingRDD[txn_id#0,city#1,product#2,category#3,amount#4,txn_date#5,status#6]
#       +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=442]
#          +- Filter isnotnull(city#42)
#             +- Scan ExistingRDD[city#42,tier#43]

# %%
#15
enriched_df.printSchema()
# Out:
# root
#  |-- city: string (nullable = true)
#  |-- txn_id: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- amount: string (nullable = true)
#  |-- txn_date: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- amount_int: integer (nullable = true)
#  |-- txn_date_parsed: date (nullable = true)
#  |-- tier: string (nullable = true)

# %% [markdown]
# PHASE 4 — ANALYTICS & WINDOW FUNCTIONS
#
# Tasks
#
# 16. Revenue per city
# 17. Revenue per product
# 18. Rank cities by total revenue
# 19. Rank products within each city
# 20. Identify top-performing city per day

# %%
#16
revenue_city=enriched_df.groupBy("city").agg(sum("amount_int").alias("total_revenue"))
revenue_city.show()

#17
revenue_product=enriched_df.groupBy("product").agg(sum("amount_int").alias("total_revenue"))
revenue_product.show()

#18
city_rank_window=Window.orderBy(desc("total_revenue"))
revenue_city=revenue_city.withColumn("city_rank",rank().over(city_rank_window))
revenue_city.show()

#19
product_city_window=Window.partitionBy("city").orderBy(desc("amount_int"))
ranked_products=enriched_df.withColumn("product_rank",rank().over(product_city_window))
ranked_products.show()

#20
daily_city_window=Window.partitionBy("txn_date_parsed").orderBy(desc("amount_int"))
top_city_daily=enriched_df.withColumn("rank",rank().over(daily_city_window)).filter(col("rank")==1)
top_city_daily.show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|        58000|
# |   Mumbai|        87000|
# |    Delhi|        90000|
# +---------+-------------+
#
# +-------+-------------+
# |product|total_revenue|
# +-------+-------------+
# | Laptop|       145000|
# | Mobile|        60000|
# | Tablet|        30000|
# +-------+-------------+
#
# +---------+-------------+---------+
# |     city|total_revenue|city_rank|
# +---------+-------------+---------+
# |    Delhi|        90000|        1|
# |   Mumbai|        87000|        2|
# |Bangalore|        58000|        3|
# +---------+-------------+---------+
#
# +---------+------+-------+-----------+------+----------+---------+----------+---------------+------+------------+
# |     city|txn_id|product|   category|amount|  txn_date|   status|amount_int|txn_date_parsed|  tier|product_rank|
# +---------+------+-------+-----------+------+----------+---------+----------+---------------+------+------------+
# |Bangalore|TXN003| Tablet|ELECTRONICS| 30000|2024/01/06|Completed|     30000|     2024-01-06|Tier-1|           1|
# |Bangalore|TXN008| Mobile|ELECTRONICS| 28000|2024-01-09|Completed|     28000|     2024-01-09|Tier-1|           2|
# |    Delhi|TXN001| Laptop|ELECTRONICS| 45000|2024-01-05|Completed|     45000|     2024-01-05|Tier-1|           1|
# |    Delhi|TXN007| Laptop|ELECTRONICS| 45000|09-01-2024|Completed|     45000|     2024-01-09|Tier-1|           1|
# |   Mumbai|TXN009| Laptop|ELECTRONICS| 55000|2024-01-10|Completed|     55000|     2024-01-10|Tier-1|           1|
# |   Mumbai|TXN002| Mobile|ELECTRONICS| 32000|05/01/2024|Completed|     32000|     2024-01-05|Tier-1|           2|
# +---------+------+-------+-----------+------+----------+---------+----------+---------------+------+------------+
#
# +---------+------+-------+-----------+------+----------+---------+----------+---------------+------+----+
# |     city|txn_id|product|   category|amount|  txn_date|   status|amount_int|txn_date_parsed|  tier|rank|
# +---------+------+-------+-----------+------+----------+---------+----------+---------------+------+----+
# |    Delhi|TXN001| Laptop|ELECTRONICS| 45000|2024-01-05|Completed|     45000|     2024-01-05|Tier-1|   1|
# |Bangalore|TXN003| Tablet|ELECTRONICS| 30000|2024/01/06|Completed|     30000|     2024-01-06|Tier-1|   1|
# |    Delhi|TXN007| Laptop|ELECTRONICS| 45000|09-01-2024|Completed|     45000|     2024-01-09|Tier-1|   1|
# |   Mumbai|TXN009| Laptop|ELECTRONICS| 55000|2024-01-10|Completed|     55000|     2024-01-10|Tier-1|   1|
# +---------+------+-------+-----------+------+----------+---------+----------+---------------+------+----+

# %% [markdown]
# PHASE 5 — CACHING, PARTITIONS & OPTIMIZATION
#
# Tasks
#
# 21. Identify reusable DataFrames
# 22. Apply caching appropriately
# 23. Compare performance with and without cache
# 24. Repartition data by city
# 25. Explain why partitioning helps

# %%
#21
#Resuable DataFrame is enriched_df

#22,23
enriched_df.cache()
enriched_df.count()
# Out:
# 6

# %%
enriched_df.groupBy("city").sum("amount_int").show()
# Out:
# +---------+---------------+
# |     city|sum(amount_int)|
# +---------+---------------+
# |Bangalore|          58000|
# |    Delhi|          90000|
# |   Mumbai|          87000|
# +---------+---------------+

# %%
#24
partitioned_df=enriched_df.repartition("city")
partitioned_df.rdd.getNumPartitions()
# Out:
# 1

# %% [markdown]
# PHASE 6 — FILE FORMAT STRATEGY
#
# Tasks
#
# 26. Write cleaned data to Parquet
# 27. Write aggregated data to ORC
# 28. Compare file structure and size
# 29. Explain why Avro is not used here
# 30. Design a future streaming ingestion using Avro

# %%
#26
partitioned_df.write.mode("overwrite").partitionBy("city").parquet("/data/clean_sales_parquet")

# %%
#27
revenue_city.write.mode("overwrite").orc("/data/agg_revenue_orc")

# %% [markdown]
# PHASE 7 — DEBUGGING & ERROR HANDLING
#
# Tasks
#
# 31. Identify common mistakes (intentional bugs)
# 32. Debug schema mismatch errors
# 33. Debug NoneType DataFrame errors
# 34. Use explain() to identify inefficiencies

# %%
sales_df.explain(True)
# Out:
# == Parsed Logical Plan ==
# LogicalRDD [txn_id#0, city#1, product#2, category#3, amount#4, txn_date#5, status#6], false
#
# == Analyzed Logical Plan ==
# txn_id: string, city: string, product: string, category: string, amount: string, txn_date: string, status: string
# LogicalRDD [txn_id#0, city#1, product#2, category#3, amount#4, txn_date#5, status#6], false
#
# == Optimized Logical Plan ==
# LogicalRDD [txn_id#0, city#1, product#2, category#3, amount#4, txn_date#5, status#6], false
#
# == Physical Plan ==
# *(1) Scan ExistingRDD[txn_id#0,city#1,product#2,category#3,amount#4,txn_date#5,status#6]

# %%
customer_df.explain(True)
# Out:
# == Parsed Logical Plan ==
# LogicalRDD [customer_id#29, city#30, segment#31], false
#
# == Analyzed Logical Plan ==
# customer_id: string, city: string, segment: string
# LogicalRDD [customer_id#29, city#30, segment#31], false
#
# == Optimized Logical Plan ==
# LogicalRDD [customer_id#29, city#30, segment#31], false
#
# == Physical Plan ==
# *(1) Scan ExistingRDD[customer_id#29,city#30,segment#31]

# %%
city_df.explain(True)
# Out:
# == Parsed Logical Plan ==
# LogicalRDD [city#42, tier#43], false
#
# == Analyzed Logical Plan ==
# city: string, tier: string
# LogicalRDD [city#42, tier#43], false
#
# == Optimized Logical Plan ==
# LogicalRDD [city#42, tier#43], false
#
# == Physical Plan ==
# *(1) Scan ExistingRDD[city#42,tier#43]

# %% [markdown]
# PHASE 8 — FINAL VALIDATION &
# DELIVERABLES
#
# Tasks
#
# 35. Validate record counts
# 36. Ensure no nulls in critical fields
# 37. Confirm schema correctness
# 38. Document optimization decisions

# %%
#35
clean_df.count()
enriched_df.count()
# Out:
# 6

# %%
#36
enriched_df.select([count(when(col(c).isNull(),c)).alias(c)
    for c in ["txn_id","city","amount_int","txn_date_parsed"]
]).show()
# Out:
# +------+----+----------+---------------+
# |txn_id|city|amount_int|txn_date_parsed|
# +------+----+----------+---------------+
# |     0|   0|         0|              0|
# +------+----+----------+---------------+

# %%
#37
enriched_df.printSchema()
# Out:
# root
#  |-- city: string (nullable = true)
#  |-- txn_id: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- amount: string (nullable = true)
#  |-- txn_date: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- amount_int: integer (nullable = true)
#  |-- txn_date_parsed: date (nullable = true)
#  |-- tier: string (nullable = true)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

spark = SparkSession.builder.appName("Customer Transactions").getOrCreate()

# %%
raw_orders = [
("ORD001","C001","Ravi"," Delhi ","Laptop","Electronics","45000","2024-01-05","Completed"),
("ORD002","C002","Sneha","Mumbai"," Mobile ","Electronics","32000","05/01/2024","Completed"),
("ORD003","C003","Aman","Bangalore","Laptop","Electronics","55000","2024/01/06","Completed"),
("ORD004","C004","Pooja","Delhi","Tablet"," Electronics ","","2024-01-07","Cancelled"),
("ORD005","C005","Neha","Chennai","Laptop","Electronics","48000","invalid_date","Completed"),
("ORD006","C006","Rahul","Mumbai","Mobile","Electronics",None,"2024-01-08","Completed"),
("ORD007","C007","Kiran","Bangalore","Tablet","Electronics","30000","2024-01-08","Completed"),
("ORD008","C008","Amit","Delhi","Laptop","electronics","45000","2024-01-09","Completed"),
("ORD009","C009","Priya"," Pune","Mobile","Electronics","28000","09-01-2024","Completed"),
("ORD010","C010","Suresh","Mumbai","Laptop","Electronics","55000","2024-01-10","Completed"),
("ORD010","C010","Suresh","Mumbai","Laptop","Electronics","55000","2024-01-10","Completed"),  #duplicate
("ORD011","C011","Meena","Chennai","Tablet","Electronics","31000","2024-01-11","Completed"),
("ORD012","C012","Arjun","Delhi","Mobile","Electronics","27000","2024/01/11","Completed"),
("ORD013","C013","Nikhil","Bangalore","Laptop","Electronics","60000","2024-01-12","Completed"),
("ORD014","C014","Rohit","Mumbai","Mobile","Electronics","invalid_price","2024-01-12","Completed"),
("ORD015","C015","Anita","Delhi","Tablet","Electronics","29000","2024-01-13","Completed"),
("ORD016","C016","Vikas","Chennai","Laptop","Electronics","52000","2024-01-13","Completed"),
("ORD017","C017","Sunita","Mumbai","Mobile","Electronics","33000","2024-01-14","Completed"),
("ORD018","C018","Deepak","Bangalore","Laptop","Electronics","58000","2024-01-14","Completed"),
("ORD019","C019","Pallavi","Delhi","Mobile","Electronics","26000","2024-01-15","Completed"),
("ORD020","C020","Manish","Mumbai","Tablet","Electronics","34000","2024-01-15","Completed")
]

# %%
schema = StructType([
    StructField("order_id", StringType(), True),
    StructField("customer_id", StringType(), True),
    StructField("customer_name", StringType(), True),
    StructField("city", StringType(), True),
    StructField("product", StringType(), True),
    StructField("category", StringType(), True),
    StructField("price", StringType(), True),
    StructField("order_date", StringType(), True),
    StructField("order_status", StringType(), True)
])

# %%
df = spark.createDataFrame(raw_orders, schema)
df.show(truncate=False)
# Out:
# +--------+-----------+-------------+---------+--------+-------------+-------------+------------+------------+
# |order_id|customer_id|customer_name|city     |product |category     |price        |order_date  |order_status|
# +--------+-----------+-------------+---------+--------+-------------+-------------+------------+------------+
# |ORD001  |C001       |Ravi         | Delhi   |Laptop  |Electronics  |45000        |2024-01-05  |Completed   |
# |ORD002  |C002       |Sneha        |Mumbai   | Mobile |Electronics  |32000        |05/01/2024  |Completed   |
# |ORD003  |C003       |Aman         |Bangalore|Laptop  |Electronics  |55000        |2024/01/06  |Completed   |
# |ORD004  |C004       |Pooja        |Delhi    |Tablet  | Electronics |             |2024-01-07  |Cancelled   |
# |ORD005  |C005       |Neha         |Chennai  |Laptop  |Electronics  |48000        |invalid_date|Completed   |
# |ORD006  |C006       |Rahul        |Mumbai   |Mobile  |Electronics  |NULL         |2024-01-08  |Completed   |
# |ORD007  |C007       |Kiran        |Bangalore|Tablet  |Electronics  |30000        |2024-01-08  |Completed   |
# |ORD008  |C008       |Amit         |Delhi    |Laptop  |electronics  |45000        |2024-01-09  |Completed   |
# |ORD009  |C009       |Priya        | Pune    |Mobile  |Electronics  |28000        |09-01-2024  |Completed   |
# |ORD010  |C010       |Suresh       |Mumbai   |Laptop  |Electronics  |55000        |2024-01-10  |Completed   |
# |ORD010  |C010       |Suresh       |Mumbai   |Laptop  |Electronics  |55000        |2024-01-10  |Completed   |
# |ORD011  |C011       |Meena        |Chennai  |Tablet  |Electronics  |31000        |2024-01-11  |Completed   |
# |ORD012  |C012       |Arjun        |Delhi    |Mobile  |Electronics  |27000        |2024/01/11  |Completed   |
# |ORD013  |C013       |Nikhil       |Bangalore|Laptop  |Electronics  |60000        |2024-01-12  |Completed   |
# |ORD014  |C014       |Rohit        |Mumbai   |Mobile  |Electronics  |invalid_price|2024-01-12  |Completed   |
# |ORD015  |C015       |Anita        |Delhi    |Tablet  |Electronics  |29000        |2024-01-13  |Completed   |
# |ORD016  |C016       |Vikas        |Chennai  |Laptop  |Electronics  |52000        |2024-01-13  |Completed   |
# |ORD017  |C017       |Sunita       |Mumbai   |Mobile  |Electronics  |33000        |2024-01-14  |Completed   |
# |ORD018  |C018       |Deepak       |Bangalore|Laptop  |Electronics  |58000        |2024-01-14  |Completed   |
# |ORD019  |C019       |Pallavi      |Delhi    |Mobile  |Electronics  |26000        |2024-01-15  |Completed   |
# +--------+-----------+-------------+---------+--------+-------------+-------------+------------+------------+
# only showing top 20 rows

# %% [markdown]
# Column Operations
# 1. Rename all columns to snake_case
# 2. Add a column price_with_tax (18%)
# 3. Add a column price_category (Low / Medium / High)
#
# Data Cleaning
#
# 4. Trim and standardize city , product , category
# 5. Convert price to integer
# 6. Handle invalid and null prices
# 7. Normalize all dates into DateType
# 8. Remove duplicate orders
# 9. Filter only Completed orders
#
# Data Transformation
#
# 10. Create order_year , order_month
# 11. Aggregate total revenue per city
# 12. Aggregate total revenue per product
# 13. Identify top 3 cities by revenue
# 14. Identify products with average price above threshold
#
# File Format Operations
#
# 15. Write cleaned data to Parquet
# 16. Read Parquet back and verify schema
# 17. Write the same data to ORC
# 18. (Optional) Write to Avro
#
# Performance & Validation
#
# 19. Check number of partitions
# 20. Repartition before writing
# 21. Compare file counts between Parquet and ORC
# 22. Run explain(True) on final pipeline

# %%
columns = [
    "order_id",
    "customer_id",
    "customer_name",
    "city",
    "product",
    "category",
    "price",
    "order_date",
    "order_status"
]

df_chg = df.toDF(*columns)
df_chg.show()
df_chg.printSchema()
# Out:
# +--------+-----------+-------------+---------+--------+-------------+-------------+------------+------------+
# |order_id|customer_id|customer_name|     city| product|     category|        price|  order_date|order_status|
# +--------+-----------+-------------+---------+--------+-------------+-------------+------------+------------+
# |  ORD001|       C001|         Ravi|   Delhi |  Laptop|  Electronics|        45000|  2024-01-05|   Completed|
# |  ORD002|       C002|        Sneha|   Mumbai| Mobile |  Electronics|        32000|  05/01/2024|   Completed|
# |  ORD003|       C003|         Aman|Bangalore|  Laptop|  Electronics|        55000|  2024/01/06|   Completed|
# |  ORD004|       C004|        Pooja|    Delhi|  Tablet| Electronics |             |  2024-01-07|   Cancelled|
# |  ORD005|       C005|         Neha|  Chennai|  Laptop|  Electronics|        48000|invalid_date|   Completed|
# |  ORD006|       C006|        Rahul|   Mumbai|  Mobile|  Electronics|         NULL|  2024-01-08|   Completed|
# |  ORD007|       C007|        Kiran|Bangalore|  Tablet|  Electronics|        30000|  2024-01-08|   Completed|
# |  ORD008|       C008|         Amit|    Delhi|  Laptop|  electronics|        45000|  2024-01-09|   Completed|
# |  ORD009|       C009|        Priya|     Pune|  Mobile|  Electronics|        28000|  09-01-2024|   Completed|
# |  ORD010|       C010|       Suresh|   Mumbai|  Laptop|  Electronics|        55000|  2024-01-10|   Completed|
# |  ORD010|       C010|       Suresh|   Mumbai|  Laptop|  Electronics|        55000|  2024-01-10|   Completed|
# |  ORD011|       C011|        Meena|  Chennai|  Tablet|  Electronics|        31000|  2024-01-11|   Completed|
# |  ORD012|       C012|        Arjun|    Delhi|  Mobile|  Electronics|        27000|  2024/01/11|   Completed|
# |  ORD013|       C013|       Nikhil|Bangalore|  Laptop|  Electronics|        60000|  2024-01-12|   Completed|
# |  ORD014|       C014|        Rohit|   Mumbai|  Mobile|  Electronics|invalid_price|  2024-01-12|   Completed|
# |  ORD015|       C015|        Anita|    Delhi|  Tablet|  Electronics|        29000|  2024-01-13|   Completed|
# |  ORD016|       C016|        Vikas|  Chennai|  Laptop|  Electronics|        52000|  2024-01-13|   Completed|
# |  ORD017|       C017|       Sunita|   Mumbai|  Mobile|  Electronics|        33000|  2024-01-14|   Completed|
# |  ORD018|       C018|       Deepak|Bangalore|  Laptop|  Electronics|        58000|  2024-01-14|   Completed|
# |  ORD019|       C019|      Pallavi|    Delhi|  Mobile|  Electronics|        26000|  2024-01-15|   Completed|
# +--------+-----------+-------------+---------+--------+-------------+-------------+------------+------------+
# only showing top 20 rows
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
#2
from pyspark.sql.functions import when, col
from pyspark.sql.types import DoubleType

df_chg = df_chg.withColumn("price",
                 when(col("price").rlike("^[0-9]+$"),col("price").cast(DoubleType())).otherwise(None))

if "price_with_tax" in df.columns:
    df_chg = df_chg.drop("price_with_tax")

df_chg = df_chg.withColumn("price_with_tax", col("price") * 1.18)

df_chg.show(5)
# Out:
# +--------+-----------+-------------+---------+-------+-----------+-------+------------+------------+--------------+
# |order_id|customer_id|customer_name|     city|product|   category|  price|  order_date|order_status|price_with_tax|
# +--------+-----------+-------------+---------+-------+-----------+-------+------------+------------+--------------+
# |  ORD001|       C001|         Ravi|    Delhi| Laptop|Electronics|45000.0|  2024-01-05|   Completed|       53100.0|
# |  ORD002|       C002|        Sneha|   Mumbai| Mobile|Electronics|32000.0|  05/01/2024|   Completed|       37760.0|
# |  ORD003|       C003|         Aman|Bangalore| Laptop|Electronics|55000.0|  2024/01/06|   Completed|       64900.0|
# |  ORD004|       C004|        Pooja|    Delhi| Tablet|Electronics|   NULL|  2024-01-07|   Cancelled|          NULL|
# |  ORD005|       C005|         Neha|  Chennai| Laptop|Electronics|48000.0|invalid_date|   Completed|       56640.0|
# +--------+-----------+-------------+---------+-------+-----------+-------+------------+------------+--------------+
# only showing top 5 rows

# %%
#3
df_chg=df_chg.withColumn("price_category",
                 when(col("price")<30000,"Low")
                 .when(col("price").between(30000,50000),"Medium")
                 .otherwise("High")
                 )
df_chg.show()
# Out:
# +--------+-----------+-------------+---------+-------+-----------+-------+------------+------------+--------------+--------------+
# |order_id|customer_id|customer_name|     city|product|   category|  price|  order_date|order_status|price_with_tax|price_category|
# +--------+-----------+-------------+---------+-------+-----------+-------+------------+------------+--------------+--------------+
# |  ORD001|       C001|         Ravi|    Delhi| Laptop|Electronics|45000.0|  2024-01-05|   Completed|       53100.0|        Medium|
# |  ORD002|       C002|        Sneha|   Mumbai| Mobile|Electronics|32000.0|  05/01/2024|   Completed|       37760.0|        Medium|
# |  ORD003|       C003|         Aman|Bangalore| Laptop|Electronics|55000.0|  2024/01/06|   Completed|       64900.0|          High|
# |  ORD004|       C004|        Pooja|    Delhi| Tablet|Electronics|   NULL|  2024-01-07|   Cancelled|          NULL|          High|
# |  ORD005|       C005|         Neha|  Chennai| Laptop|Electronics|48000.0|invalid_date|   Completed|       56640.0|        Medium|
# |  ORD006|       C006|        Rahul|   Mumbai| Mobile|Electronics|   NULL|  2024-01-08|   Completed|          NULL|          High|
# |  ORD007|       C007|        Kiran|Bangalore| Tablet|Electronics|30000.0|  2024-01-08|   Completed|       35400.0|        Medium|
# |  ORD008|       C008|         Amit|    Delhi| Laptop|Electronics|45000.0|  2024-01-09|   Completed|       53100.0|        Medium|
# |  ORD009|       C009|        Priya|     Pune| Mobile|Electronics|28000.0|  09-01-2024|   Completed|       33040.0|           Low|
# |  ORD010|       C010|       Suresh|   Mumbai| Laptop|Electronics|55000.0|  2024-01-10|   Completed|       64900.0|          High|
# |  ORD010|       C010|       Suresh|   Mumbai| Laptop|Electronics|55000.0|  2024-01-10|   Completed|       64900.0|          High|
# |  ORD011|       C011|        Meena|  Chennai| Tablet|Electronics|31000.0|  2024-01-11|   Completed|       36580.0|        Medium|
# |  ORD012|       C012|        Arjun|    Delhi| Mobile|Electronics|27000.0|  2024/01/11|   Completed|       31860.0|           Low|
# |  ORD013|       C013|       Nikhil|Bangalore| Laptop|Electronics|60000.0|  2024-01-12|   Completed|       70800.0|          High|
# |  ORD014|       C014|        Rohit|   Mumbai| Mobile|Electronics|   NULL|  2024-01-12|   Completed|          NULL|          High|
# |  ORD015|       C015|        Anita|    Delhi| Tablet|Electronics|29000.0|  2024-01-13|   Completed|       34220.0|           Low|
# |  ORD016|       C016|        Vikas|  Chennai| Laptop|Electronics|52000.0|  2024-01-13|   Completed|       61360.0|          High|
# |  ORD017|       C017|       Sunita|   Mumbai| Mobile|Electronics|33000.0|  2024-01-14|   Completed|       38940.0|        Medium|
# |  ORD018|       C018|       Deepak|Bangalore| Laptop|Electronics|58000.0|  2024-01-14|   Completed|       68440.0|          High|
# |  ORD019|       C019|      Pallavi|    Delhi| Mobile|Electronics|26000.0|  2024-01-15|   Completed|       30680.0|           Low|
# +--------+-----------+-------------+---------+-------+-----------+-------+------------+------------+--------------+--------------+
# only showing top 20 rows

# %%
#4
df_chg = df_chg.withColumn("city", trim(initcap(col("city")))) \
       .withColumn("product", trim(initcap(col("product")))) \
       .withColumn("category", trim(initcap(col("category")))) \
       .withColumn("order_status", trim(initcap(col("order_status"))))
df_chg.show()
# Out:
# +--------+-----------+-------------+---------+-------+-----------+-------+------------+------------+--------------+--------------+
# |order_id|customer_id|customer_name|     city|product|   category|  price|  order_date|order_status|price_with_tax|price_category|
# +--------+-----------+-------------+---------+-------+-----------+-------+------------+------------+--------------+--------------+
# |  ORD001|       C001|         Ravi|    Delhi| Laptop|Electronics|45000.0|  2024-01-05|   Completed|       53100.0|        Medium|
# |  ORD002|       C002|        Sneha|   Mumbai| Mobile|Electronics|32000.0|  05/01/2024|   Completed|       37760.0|        Medium|
# |  ORD003|       C003|         Aman|Bangalore| Laptop|Electronics|55000.0|  2024/01/06|   Completed|       64900.0|          High|
# |  ORD004|       C004|        Pooja|    Delhi| Tablet|Electronics|   NULL|  2024-01-07|   Cancelled|          NULL|          High|
# |  ORD005|       C005|         Neha|  Chennai| Laptop|Electronics|48000.0|invalid_date|   Completed|       56640.0|        Medium|
# |  ORD006|       C006|        Rahul|   Mumbai| Mobile|Electronics|   NULL|  2024-01-08|   Completed|          NULL|          High|
# |  ORD007|       C007|        Kiran|Bangalore| Tablet|Electronics|30000.0|  2024-01-08|   Completed|       35400.0|        Medium|
# |  ORD008|       C008|         Amit|    Delhi| Laptop|Electronics|45000.0|  2024-01-09|   Completed|       53100.0|        Medium|
# |  ORD009|       C009|        Priya|     Pune| Mobile|Electronics|28000.0|  09-01-2024|   Completed|       33040.0|           Low|
# |  ORD010|       C010|       Suresh|   Mumbai| Laptop|Electronics|55000.0|  2024-01-10|   Completed|       64900.0|          High|
# |  ORD010|       C010|       Suresh|   Mumbai| Laptop|Electronics|55000.0|  2024-01-10|   Completed|       64900.0|          High|
# |  ORD011|       C011|        Meena|  Chennai| Tablet|Electronics|31000.0|  2024-01-11|   Completed|       36580.0|        Medium|
# |  ORD012|       C012|        Arjun|    Delhi| Mobile|Electronics|27000.0|  2024/01/11|   Completed|       31860.0|           Low|
# |  ORD013|       C013|       Nikhil|Bangalore| Laptop|Electronics|60000.0|  2024-01-12|   Completed|       70800.0|          High|
# |  ORD014|       C014|        Rohit|   Mumbai| Mobile|Electronics|   NULL|  2024-01-12|   Completed|          NULL|          High|
# |  ORD015|       C015|        Anita|    Delhi| Tablet|Electronics|29000.0|  2024-01-13|   Completed|       34220.0|           Low|
# |  ORD016|       C016|        Vikas|  Chennai| Laptop|Electronics|52000.0|  2024-01-13|   Completed|       61360.0|          High|
# |  ORD017|       C017|       Sunita|   Mumbai| Mobile|Electronics|33000.0|  2024-01-14|   Completed|       38940.0|        Medium|
# |  ORD018|       C018|       Deepak|Bangalore| Laptop|Electronics|58000.0|  2024-01-14|   Completed|       68440.0|          High|
# |  ORD019|       C019|      Pallavi|    Delhi| Mobile|Electronics|26000.0|  2024-01-15|   Completed|       30680.0|           Low|
# +--------+-----------+-------------+---------+-------+-----------+-------+------------+------------+--------------+--------------+
# only showing top 20 rows

# %%
#5
from pyspark.sql.types import IntegerType

df_chg = df_chg.withColumn("price", col("price").cast(IntegerType()))
df_chg.show(5)
df_chg.printSchema()
# Out:
# +--------+-----------+-------------+---------+-------+-----------+-----+------------+------------+--------------+--------------+
# |order_id|customer_id|customer_name|     city|product|   category|price|  order_date|order_status|price_with_tax|price_category|
# +--------+-----------+-------------+---------+-------+-----------+-----+------------+------------+--------------+--------------+
# |  ORD001|       C001|         Ravi|    Delhi| Laptop|Electronics|45000|  2024-01-05|   Completed|       53100.0|        Medium|
# |  ORD002|       C002|        Sneha|   Mumbai| Mobile|Electronics|32000|  05/01/2024|   Completed|       37760.0|        Medium|
# |  ORD003|       C003|         Aman|Bangalore| Laptop|Electronics|55000|  2024/01/06|   Completed|       64900.0|          High|
# |  ORD004|       C004|        Pooja|    Delhi| Tablet|Electronics| NULL|  2024-01-07|   Cancelled|          NULL|          High|
# |  ORD005|       C005|         Neha|  Chennai| Laptop|Electronics|48000|invalid_date|   Completed|       56640.0|        Medium|
# +--------+-----------+-------------+---------+-------+-----------+-----+------------+------------+--------------+--------------+
# only showing top 5 rows
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- price_with_tax: double (nullable = true)
#  |-- price_category: string (nullable = false)

# %%
#6
from pyspark.sql.functions import mean, col, when
from pyspark.sql.types import IntegerType, DoubleType

mean_price = df_chg.agg(mean(col("price"))).collect()[0][0]

df_chg = df_chg.withColumn("price", when(col("price").isNull(), mean_price).otherwise(col("price")))

df_chg = df_chg.withColumn("price", col("price").cast(IntegerType()))

df_chg = df_chg.withColumn("price_with_tax", col("price").cast(DoubleType()) * 1.18)

df_chg = df_chg.withColumn("price_category",
                 when(col("price") < 30000, "Low")
                 .when(col("price").between(30000, 50000), "Medium")
                 .otherwise("High"))

df_chg.show(5)
df_chg.printSchema()
# Out:
# +--------+-----------+-------------+---------+-------+-----------+-----+------------+------------+--------------+--------------+
# |order_id|customer_id|customer_name|     city|product|   category|price|  order_date|order_status|price_with_tax|price_category|
# +--------+-----------+-------------+---------+-------+-----------+-----+------------+------------+--------------+--------------+
# |  ORD001|       C001|         Ravi|    Delhi| Laptop|Electronics|45000|  2024-01-05|   Completed|       53100.0|        Medium|
# |  ORD002|       C002|        Sneha|   Mumbai| Mobile|Electronics|32000|  05/01/2024|   Completed|       37760.0|        Medium|
# |  ORD003|       C003|         Aman|Bangalore| Laptop|Electronics|55000|  2024/01/06|   Completed|       64900.0|          High|
# |  ORD004|       C004|        Pooja|    Delhi| Tablet|Electronics|41277|  2024-01-07|   Cancelled|      48706.86|        Medium|
# |  ORD005|       C005|         Neha|  Chennai| Laptop|Electronics|48000|invalid_date|   Completed|       56640.0|        Medium|
# +--------+-----------+-------------+---------+-------+-----------+-----+------------+------------+--------------+--------------+
# only showing top 5 rows
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- price_with_tax: double (nullable = true)
#  |-- price_category: string (nullable = false)

# %%
#7
from pyspark.sql.functions import udf
from pyspark.sql.types import DateType
from datetime import datetime


from pyspark.sql.functions import coalesce, to_date


from pyspark.sql.functions import udf, col, trim
from pyspark.sql.types import DateType
from datetime import datetime

def parse_date_py(date_str):
    if date_str is None:
        return None
    date_str = date_str.strip()
    formats = ["%Y-%m-%d", "%d-%m-%Y", "%m/%d/%Y", "%Y/%m/%d"]
    for fmt in formats:
        try:
            return datetime.strptime(date_str, fmt).date()
        except ValueError:
            continue
    return None

parse_date_udf = udf(parse_date_py, DateType())

df_chg = df_chg.withColumn("order_date", parse_date_udf(col("order_date")))

df_chg.show(truncate=False)
df_chg.printSchema()
# Out:
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+
# |order_id|customer_id|customer_name|city     |product|category   |price|order_date|order_status|price_with_tax|price_category|
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+
# |ORD001  |C001       |Ravi         |Delhi    |Laptop |Electronics|45000|2024-01-05|Completed   |53100.0       |Medium        |
# |ORD002  |C002       |Sneha        |Mumbai   |Mobile |Electronics|32000|2024-05-01|Completed   |37760.0       |Medium        |
# |ORD003  |C003       |Aman         |Bangalore|Laptop |Electronics|55000|2024-01-06|Completed   |64900.0       |High          |
# |ORD004  |C004       |Pooja        |Delhi    |Tablet |Electronics|41277|2024-01-07|Cancelled   |48706.86      |Medium        |
# |ORD005  |C005       |Neha         |Chennai  |Laptop |Electronics|48000|NULL      |Completed   |56640.0       |Medium        |
# |ORD006  |C006       |Rahul        |Mumbai   |Mobile |Electronics|41277|2024-01-08|Completed   |48706.86      |Medium        |
# |ORD007  |C007       |Kiran        |Bangalore|Tablet |Electronics|30000|2024-01-08|Completed   |35400.0       |Medium        |
# |ORD008  |C008       |Amit         |Delhi    |Laptop |Electronics|45000|2024-01-09|Completed   |53100.0       |Medium        |
# |ORD009  |C009       |Priya        |Pune     |Mobile |Electronics|28000|2024-01-09|Completed   |33040.0       |Low           |
# |ORD010  |C010       |Suresh       |Mumbai   |Laptop |Electronics|55000|2024-01-10|Completed   |64900.0       |High          |
# |ORD010  |C010       |Suresh       |Mumbai   |Laptop |Electronics|55000|2024-01-10|Completed   |64900.0       |High          |
# |ORD011  |C011       |Meena        |Chennai  |Tablet |Electronics|31000|2024-01-11|Completed   |36580.0       |Medium        |
# |ORD012  |C012       |Arjun        |Delhi    |Mobile |Electronics|27000|2024-01-11|Completed   |31860.0       |Low           |
# |ORD013  |C013       |Nikhil       |Bangalore|Laptop |Electronics|60000|2024-01-12|Completed   |70800.0       |High          |
# |ORD014  |C014       |Rohit        |Mumbai   |Mobile |Electronics|41277|2024-01-12|Completed   |48706.86      |Medium        |
# |ORD015  |C015       |Anita        |Delhi    |Tablet |Electronics|29000|2024-01-13|Completed   |34220.0       |Low           |
# |ORD016  |C016       |Vikas        |Chennai  |Laptop |Electronics|52000|2024-01-13|Completed   |61360.0       |High          |
# |ORD017  |C017       |Sunita       |Mumbai   |Mobile |Electronics|33000|2024-01-14|Completed   |38940.0       |Medium        |
# |ORD018  |C018       |Deepak       |Bangalore|Laptop |Electronics|58000|2024-01-14|Completed   |68440.0       |High          |
# |ORD019  |C019       |Pallavi      |Delhi    |Mobile |Electronics|26000|2024-01-15|Completed   |30680.0       |Low           |
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+
# only showing top 20 rows
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- price_with_tax: double (nullable = true)
#  |-- price_category: string (nullable = false)

# %%
#8
df_chg = df_chg.dropDuplicates(["order_id"])
df_chg.show()
# Out:
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+
# |order_id|customer_id|customer_name|     city|product|   category|price|order_date|order_status|price_with_tax|price_category|
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+
# |  ORD001|       C001|         Ravi|    Delhi| Laptop|Electronics|45000|2024-01-05|   Completed|       53100.0|        Medium|
# |  ORD002|       C002|        Sneha|   Mumbai| Mobile|Electronics|32000|2024-05-01|   Completed|       37760.0|        Medium|
# |  ORD003|       C003|         Aman|Bangalore| Laptop|Electronics|55000|2024-01-06|   Completed|       64900.0|          High|
# |  ORD004|       C004|        Pooja|    Delhi| Tablet|Electronics|41277|2024-01-07|   Cancelled|      48706.86|        Medium|
# |  ORD005|       C005|         Neha|  Chennai| Laptop|Electronics|48000|      NULL|   Completed|       56640.0|        Medium|
# |  ORD006|       C006|        Rahul|   Mumbai| Mobile|Electronics|41277|2024-01-08|   Completed|      48706.86|        Medium|
# |  ORD007|       C007|        Kiran|Bangalore| Tablet|Electronics|30000|2024-01-08|   Completed|       35400.0|        Medium|
# |  ORD008|       C008|         Amit|    Delhi| Laptop|Electronics|45000|2024-01-09|   Completed|       53100.0|        Medium|
# |  ORD009|       C009|        Priya|     Pune| Mobile|Electronics|28000|2024-01-09|   Completed|       33040.0|           Low|
# |  ORD010|       C010|       Suresh|   Mumbai| Laptop|Electronics|55000|2024-01-10|   Completed|       64900.0|          High|
# |  ORD011|       C011|        Meena|  Chennai| Tablet|Electronics|31000|2024-01-11|   Completed|       36580.0|        Medium|
# |  ORD012|       C012|        Arjun|    Delhi| Mobile|Electronics|27000|2024-01-11|   Completed|       31860.0|           Low|
# |  ORD013|       C013|       Nikhil|Bangalore| Laptop|Electronics|60000|2024-01-12|   Completed|       70800.0|          High|
# |  ORD014|       C014|        Rohit|   Mumbai| Mobile|Electronics|41277|2024-01-12|   Completed|      48706.86|        Medium|
# |  ORD015|       C015|        Anita|    Delhi| Tablet|Electronics|29000|2024-01-13|   Completed|       34220.0|           Low|
# |  ORD016|       C016|        Vikas|  Chennai| Laptop|Electronics|52000|2024-01-13|   Completed|       61360.0|          High|
# |  ORD017|       C017|       Sunita|   Mumbai| Mobile|Electronics|33000|2024-01-14|   Completed|       38940.0|        Medium|
# |  ORD018|       C018|       Deepak|Bangalore| Laptop|Electronics|58000|2024-01-14|   Completed|       68440.0|          High|
# |  ORD019|       C019|      Pallavi|    Delhi| Mobile|Electronics|26000|2024-01-15|   Completed|       30680.0|           Low|
# |  ORD020|       C020|       Manish|   Mumbai| Tablet|Electronics|34000|2024-01-15|   Completed|       40120.0|        Medium|
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+

# %%
#9
df_chg=df_chg.filter(col("order_status")=="Completed")
df_chg.show()
# Out:
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+
# |order_id|customer_id|customer_name|     city|product|   category|price|order_date|order_status|price_with_tax|price_category|
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+
# |  ORD001|       C001|         Ravi|    Delhi| Laptop|Electronics|45000|2024-01-05|   Completed|       53100.0|        Medium|
# |  ORD002|       C002|        Sneha|   Mumbai| Mobile|Electronics|32000|2024-05-01|   Completed|       37760.0|        Medium|
# |  ORD003|       C003|         Aman|Bangalore| Laptop|Electronics|55000|2024-01-06|   Completed|       64900.0|          High|
# |  ORD005|       C005|         Neha|  Chennai| Laptop|Electronics|48000|      NULL|   Completed|       56640.0|        Medium|
# |  ORD006|       C006|        Rahul|   Mumbai| Mobile|Electronics|41277|2024-01-08|   Completed|      48706.86|        Medium|
# |  ORD007|       C007|        Kiran|Bangalore| Tablet|Electronics|30000|2024-01-08|   Completed|       35400.0|        Medium|
# |  ORD008|       C008|         Amit|    Delhi| Laptop|Electronics|45000|2024-01-09|   Completed|       53100.0|        Medium|
# |  ORD009|       C009|        Priya|     Pune| Mobile|Electronics|28000|2024-01-09|   Completed|       33040.0|           Low|
# |  ORD010|       C010|       Suresh|   Mumbai| Laptop|Electronics|55000|2024-01-10|   Completed|       64900.0|          High|
# |  ORD011|       C011|        Meena|  Chennai| Tablet|Electronics|31000|2024-01-11|   Completed|       36580.0|        Medium|
# |  ORD012|       C012|        Arjun|    Delhi| Mobile|Electronics|27000|2024-01-11|   Completed|       31860.0|           Low|
# |  ORD013|       C013|       Nikhil|Bangalore| Laptop|Electronics|60000|2024-01-12|   Completed|       70800.0|          High|
# |  ORD014|       C014|        Rohit|   Mumbai| Mobile|Electronics|41277|2024-01-12|   Completed|      48706.86|        Medium|
# |  ORD015|       C015|        Anita|    Delhi| Tablet|Electronics|29000|2024-01-13|   Completed|       34220.0|           Low|
# |  ORD016|       C016|        Vikas|  Chennai| Laptop|Electronics|52000|2024-01-13|   Completed|       61360.0|          High|
# |  ORD017|       C017|       Sunita|   Mumbai| Mobile|Electronics|33000|2024-01-14|   Completed|       38940.0|        Medium|
# |  ORD018|       C018|       Deepak|Bangalore| Laptop|Electronics|58000|2024-01-14|   Completed|       68440.0|          High|
# |  ORD019|       C019|      Pallavi|    Delhi| Mobile|Electronics|26000|2024-01-15|   Completed|       30680.0|           Low|
# |  ORD020|       C020|       Manish|   Mumbai| Tablet|Electronics|34000|2024-01-15|   Completed|       40120.0|        Medium|
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+

# %%
#10
from pyspark.sql.functions import year,month
df_chg=df_chg.withColumn("order_year",year(col("order_date"))).withColumn("order_month",month(col("order_date")))
df_chg.show()
# Out:
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+----------+-----------+
# |order_id|customer_id|customer_name|     city|product|   category|price|order_date|order_status|price_with_tax|price_category|order_year|order_month|
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+----------+-----------+
# |  ORD001|       C001|         Ravi|    Delhi| Laptop|Electronics|45000|2024-01-05|   Completed|       53100.0|        Medium|      2024|          1|
# |  ORD002|       C002|        Sneha|   Mumbai| Mobile|Electronics|32000|2024-05-01|   Completed|       37760.0|        Medium|      2024|          5|
# |  ORD003|       C003|         Aman|Bangalore| Laptop|Electronics|55000|2024-01-06|   Completed|       64900.0|          High|      2024|          1|
# |  ORD005|       C005|         Neha|  Chennai| Laptop|Electronics|48000|      NULL|   Completed|       56640.0|        Medium|      NULL|       NULL|
# |  ORD006|       C006|        Rahul|   Mumbai| Mobile|Electronics|41277|2024-01-08|   Completed|      48706.86|        Medium|      2024|          1|
# |  ORD007|       C007|        Kiran|Bangalore| Tablet|Electronics|30000|2024-01-08|   Completed|       35400.0|        Medium|      2024|          1|
# |  ORD008|       C008|         Amit|    Delhi| Laptop|Electronics|45000|2024-01-09|   Completed|       53100.0|        Medium|      2024|          1|
# |  ORD009|       C009|        Priya|     Pune| Mobile|Electronics|28000|2024-01-09|   Completed|       33040.0|           Low|      2024|          1|
# |  ORD010|       C010|       Suresh|   Mumbai| Laptop|Electronics|55000|2024-01-10|   Completed|       64900.0|          High|      2024|          1|
# |  ORD011|       C011|        Meena|  Chennai| Tablet|Electronics|31000|2024-01-11|   Completed|       36580.0|        Medium|      2024|          1|
# |  ORD012|       C012|        Arjun|    Delhi| Mobile|Electronics|27000|2024-01-11|   Completed|       31860.0|           Low|      2024|          1|
# |  ORD013|       C013|       Nikhil|Bangalore| Laptop|Electronics|60000|2024-01-12|   Completed|       70800.0|          High|      2024|          1|
# |  ORD014|       C014|        Rohit|   Mumbai| Mobile|Electronics|41277|2024-01-12|   Completed|      48706.86|        Medium|      2024|          1|
# |  ORD015|       C015|        Anita|    Delhi| Tablet|Electronics|29000|2024-01-13|   Completed|       34220.0|           Low|      2024|          1|
# |  ORD016|       C016|        Vikas|  Chennai| Laptop|Electronics|52000|2024-01-13|   Completed|       61360.0|          High|      2024|          1|
# |  ORD017|       C017|       Sunita|   Mumbai| Mobile|Electronics|33000|2024-01-14|   Completed|       38940.0|        Medium|      2024|          1|
# |  ORD018|       C018|       Deepak|Bangalore| Laptop|Electronics|58000|2024-01-14|   Completed|       68440.0|          High|      2024|          1|
# |  ORD019|       C019|      Pallavi|    Delhi| Mobile|Electronics|26000|2024-01-15|   Completed|       30680.0|           Low|      2024|          1|
# |  ORD020|       C020|       Manish|   Mumbai| Tablet|Electronics|34000|2024-01-15|   Completed|       40120.0|        Medium|      2024|          1|
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+------------+--------------+--------------+----------+-----------+

# %%
#11
from pyspark.sql.functions import sum
revenue_city=df_chg.groupBy("city").agg(sum("price").alias("total_revenue"))
revenue_city.show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|       203000|
# |  Chennai|       131000|
# |   Mumbai|       236554|
# |     Pune|        28000|
# |    Delhi|       172000|
# +---------+-------------+

# %%
#12
revenue_product=df_chg.groupBy("product").agg(sum("price").alias("total_revenue"))
revenue_product.show()
# Out:
# +-------+-------------+
# |product|total_revenue|
# +-------+-------------+
# | Laptop|       418000|
# | Mobile|       228554|
# | Tablet|       124000|
# +-------+-------------+

# %%
#13
top_cities=revenue_city.orderBy(col("total_revenue").desc()).limit(3)
top_cities.show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |   Mumbai|       236554|
# |Bangalore|       203000|
# |    Delhi|       172000|
# +---------+-------------+

# %%
#14
avg_price_threshold=40000
premium_products=df_chg.groupBy("product").agg(avg("price").alias("average_price")).filter(col("average_price")> avg_price_threshold)
premium_products=premium_products.orderBy(col("average_price").desc())
premium_products.show()
# Out:
# +-------+-------------+
# |product|average_price|
# +-------+-------------+
# | Laptop|      52250.0|
# +-------+-------------+

# %%
#15
df_chg=df_chg.repartition(2)
df_chg.write.mode("overwrite").parquet("cleaned_data.parquet")

# %%
#16
parquet_df=spark.read.parquet("cleaned_data.parquet")
parquet_df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- price_with_tax: double (nullable = true)
#  |-- price_category: string (nullable = true)
#  |-- order_year: integer (nullable = true)
#  |-- order_month: integer (nullable = true)

# %%
#17
df_chg.write.mode("overwrite").orc("cleaned_data.orc")

# %%
#19
df_chg.rdd.getNumPartitions()
# Out:
# 2

# %%
#20
df_repartitioned = df_chg.repartition(4)
df_repartitioned.write.mode("overwrite").orc("cleaned_data_repartitioned.orc")
print(f"DataFrame repartitioned to {df_repartitioned.rdd.getNumPartitions()} partitions and written to 'cleaned_data_repartitioned.orc'")
# Out:
# DataFrame repartitioned to 4 partitions and written to 'cleaned_data_repartitioned.orc'

# %%
#21
spark.read.parquet("cleaned_data.parquet").inputFiles()
spark.read.orc("cleaned_data.orc").inputFiles()
# Out:
# ['file:///content/cleaned_data.orc/part-00000-ef54b117-374d-43aa-90b2-b3a2ec389c00-c000.zstd.orc',
#  'file:///content/cleaned_data.orc/part-00001-ef54b117-374d-43aa-90b2-b3a2ec389c00-c000.zstd.orc']

# %%
#22
df_chg.explain(True)
# Out:
# == Parsed Logical Plan ==
# Repartition 2, true
# +- Repartition 2, true
#    +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2899, order_date#2937, order_status#2809, price_with_tax#2900, price_category#2901, order_year#3235, month(order_date#2937) AS order_month#3236]
#       +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2899, order_date#2937, order_status#2809, price_with_tax#2900, price_category#2901, year(order_date#2937) AS order_year#3235]
#          +- Filter (order_status#2809 = Completed)
#             +- Deduplicate [order_id#1089]
#                +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2899, parse_date_py(order_date#1096)#2936 AS order_date#2937, order_status#2809, price_with_tax#2900, price_category#2901]
#                   +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2899, order_date#1096, order_status#2809, price_with_tax#2900, CASE WHEN (price#2899 < 30000) THEN Low WHEN ((price#2899 >= 30000) AND (price#2899 <= 50000)) THEN Medium ELSE High END AS price_category#2901]
#                      +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2899, order_date#1096, order_status#2809, (cast(price#2899 as double) * 1.18) AS price_with_tax#2900, price_category#2771]
#                         +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, cast(price#2898 as int) AS price#2899, order_date#1096, order_status#2809, price_with_tax#2739, price_category#2771]
#                            +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, CASE WHEN isnull(price#2844) THEN 41277.77777777778 ELSE cast(price#2844 as double) END AS price#2898, order_date#1096, order_status#2809, price_with_tax#2739, price_category#2771]
#                               +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, cast(price#2738 as int) AS price#2844, order_date#1096, order_status#2809, price_with_tax#2739, price_category#2771]
#                                  +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2738, order_date#1096, trim(initcap(order_status#1197), None) AS order_status#2809, price_with_tax#2739, price_category#2771]
#                                     +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, trim(initcap(category#1196), None) AS category#2808, price#2738, order_date#1096, order_status#1197, price_with_tax#2739, price_category#2771]
#                                        +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, trim(initcap(product#1195), None) AS product#2807, category#1196, price#2738, order_date#1096, order_status#1197, price_with_tax#2739, price_category#2771]
#                                           +- Project [order_id#1089, customer_id#1090, customer_name#1091, trim(initcap(city#1194), None) AS city#2806, product#1195, category#1196, price#2738, order_date#1096, order_status#1197, price_with_tax#2739, price_category#2771]
#                                              +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, product#1195, category#1196, price#2738, order_date#1096, order_status#1197, price_with_tax#2739, CASE WHEN (price#2738 < cast(30000 as double)) THEN Low WHEN ((price#2738 >= cast(30000 as double)) AND (price#2738 <= cast(50000 as double))) THEN Medium ELSE High END AS price_category#2771]
#                                                 +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, product#1195, category#1196, price#2738, order_date#1096, order_status#1197, (price#2738 * 1.18) AS price_with_tax#2739]
#                                                    +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, product#1195, category#1196, CASE WHEN RLIKE(price#1095, ^[0-9]+$) THEN cast(price#1095 as double) ELSE cast(null as double) END AS price#2738, order_date#1096, order_status#1197]
#                                                       +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, product#1195, category#1196, price#1095, order_date#1096, trim(initcap(order_status#1097), None) AS order_status#1197]
#                                                          +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, product#1195, trim(initcap(category#1094), None) AS category#1196, price#1095, order_date#1096, order_status#1097]
#                                                             +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, trim(initcap(product#1093), None) AS product#1195, category#1094, price#1095, order_date#1096, order_status#1097]
#                                                                +- Project [order_id#1089, customer_id#1090, customer_name#1091, trim(initcap(city#1092), None) AS city#1194, product#1093, category#1094, price#1095, order_date#1096, order_status#1097]
#                                                                   +- Project [order_id#0 AS order_id#1089, customer_id#1 AS customer_id#1090, customer_name#2 AS customer_name#1091, city#3 AS city#1092, product#4 AS product#1093, category#5 AS category#1094, price#6 AS price#1095, order_date#7 AS order_date#1096, order_status#8 AS order_status#1097]
#                                                                      +- LogicalRDD [order_id#0, customer_id#1, customer_name#2, city#3, product#4, category#5, price#6, order_date#7, order_status#8], false
#
# == Analyzed Logical Plan ==
# order_id: string, customer_id: string, customer_name: string, city: string, product: string, category: string, price: int, order_date: date, order_status: string, price_with_tax: double, price_category: string, order_year: int, order_month: int
# Repartition 2, true
# +- Repartition 2, true
#    +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2899, order_date#2937, order_status#2809, price_with_tax#2900, price_category#2901, order_year#3235, month(order_date#2937) AS order_month#3236]
#       +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2899, order_date#2937, order_status#2809, price_with_tax#2900, price_category#2901, year(order_date#2937) AS order_year#3235]
#          +- Filter (order_status#2809 = Completed)
#             +- Deduplicate [order_id#1089]
#                +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2899, parse_date_py(order_date#1096)#2936 AS order_date#2937, order_status#2809, price_with_tax#2900, price_category#2901]
#                   +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2899, order_date#1096, order_status#2809, price_with_tax#2900, CASE WHEN (price#2899 < 30000) THEN Low WHEN ((price#2899 >= 30000) AND (price#2899 <= 50000)) THEN Medium ELSE High END AS price_category#2901]
#                      +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2899, order_date#1096, order_status#2809, (cast(price#2899 as double) * 1.18) AS price_with_tax#2900, price_category#2771]
#                         +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, cast(price#2898 as int) AS price#2899, order_date#1096, order_status#2809, price_with_tax#2739, price_category#2771]
#                            +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, CASE WHEN isnull(price#2844) THEN 41277.77777777778 ELSE cast(price#2844 as double) END AS price#2898, order_date#1096, order_status#2809, price_with_tax#2739, price_category#2771]
#                               +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, cast(price#2738 as int) AS price#2844, order_date#1096, order_status#2809, price_with_tax#2739, price_category#2771]
#                                  +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, category#2808, price#2738, order_date#1096, trim(initcap(order_status#1197), None) AS order_status#2809, price_with_tax#2739, price_category#2771]
#                                     +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, product#2807, trim(initcap(category#1196), None) AS category#2808, price#2738, order_date#1096, order_status#1197, price_with_tax#2739, price_category#2771]
#                                        +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#2806, trim(initcap(product#1195), None) AS product#2807, category#1196, price#2738, order_date#1096, order_status#1197, price_with_tax#2739, price_category#2771]
#                                           +- Project [order_id#1089, customer_id#1090, customer_name#1091, trim(initcap(city#1194), None) AS city#2806, product#1195, category#1196, price#2738, order_date#1096, order_status#1197, price_with_tax#2739, price_category#2771]
#                                              +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, product#1195, category#1196, price#2738, order_date#1096, order_status#1197, price_with_tax#2739, CASE WHEN (price#2738 < cast(30000 as double)) THEN Low WHEN ((price#2738 >= cast(30000 as double)) AND (price#2738 <= cast(50000 as double))) THEN Medium ELSE High END AS price_category#2771]
#                                                 +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, product#1195, category#1196, price#2738, order_date#1096, order_status#1197, (price#2738 * 1.18) AS price_with_tax#2739]
#                                                    +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, product#1195, category#1196, CASE WHEN RLIKE(price#1095, ^[0-9]+$) THEN cast(price#1095 as double) ELSE cast(null as double) END AS price#2738, order_date#1096, order_status#1197]
#                                                       +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, product#1195, category#1196, price#1095, order_date#1096, trim(initcap(order_status#1097), None) AS order_status#1197]
#                                                          +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, product#1195, trim(initcap(category#1094), None) AS category#1196, price#1095, order_date#1096, order_status#1097]
#                                                             +- Project [order_id#1089, customer_id#1090, customer_name#1091, city#1194, trim(initcap(product#1093), None) AS product#1195, category#1094, price#1095, order_date#1096, order_status#1097]
#                                                                +- Project [order_id#1089, customer_id#1090, customer_name#1091, trim(initcap(city#1092), None) AS city#1194, product#1093, category#1094, price#1095, order_date#1096, order_status#1097]
#                                                                   +- Project [order_id#0 AS order_id#1089, customer_id#1 AS customer_id#1090, customer_name#2 AS customer_name#1091, city#3 AS city#1092, product#4 AS product#1093, category#5 AS category#1094, price#6 AS price#1095, order_date#7 AS order_date#1096, order_status#8 AS order_status#1097]
#                                                                      +- LogicalRDD [order_id#0, customer_id#1, customer_name#2, city#3, product#4, category#5, price#6, order_date#7, order_status#8], false
#
# == Optimized Logical Plan ==
# Repartition 2, true
# +- Project [order_id#0, customer_id#4250, customer_name#4252, city#4254, product#4256, category#4258, price#4260, order_date#4262, order_status#4264, price_with_tax#4266, price_category#4268, year(order_date#4262) AS order_year#3235, month(order_date#4262) AS order_month#3236]
#    +- Filter (isnotnull(order_status#4264) AND (order_status#4264 = Completed))
#       +- Aggregate [order_id#0], [order_id#0, first(customer_id#1, false) AS customer_id#4250, first(customer_name#2, false) AS customer_name#4252, first(city#2806, false) AS city#4254, first(product#2807, false) AS product#4256, first(category#2808, false) AS category#4258, first(price#2899, false) AS price#4260, first(order_date#2937, false) AS order_date#4262, first(order_status#2809, false) AS order_status#4264, first(price_with_tax#2900, false) AS price_with_tax#4266, first(price_category#2901, false) AS price_category#4268]
#          +- Project [order_id#0, customer_id#1, customer_name#2, city#2806, product#2807, category#2808, price#2899, pythonUDF0#4269 AS order_date#2937, order_status#2809, (cast(price#2899 as double) * 1.18) AS price_with_tax#2900, CASE WHEN (price#2899 < 30000) THEN Low WHEN ((price#2899 >= 30000) AND (price#2899 <= 50000)) THEN Medium ELSE High END AS price_category#2901]
#             +- BatchEvalPython [parse_date_py(order_date#7)#2936], [pythonUDF0#4269]
#                +- Project [order_id#0, customer_id#1, customer_name#2, city#2806, product#2807, category#2808, CASE WHEN isnull(price#2844) THEN 41277 ELSE cast(cast(price#2844 as double) as int) END AS price#2899, order_date#7, order_status#2809]
#                   +- Project [order_id#0, customer_id#1, customer_name#2, trim(initcap(trim(initcap(city#3), None)), None) AS city#2806, trim(initcap(trim(initcap(product#4), None)), None) AS product#2807, trim(initcap(trim(initcap(category#5), None)), None) AS category#2808, CASE WHEN RLIKE(price#6, ^[0-9]+$) THEN cast(cast(price#6 as double) as int) END AS price#2844, order_date#7, trim(initcap(trim(initcap(order_status#8), None)), None) AS order_status#2809]
#                      +- LogicalRDD [order_id#0, customer_id#1, customer_name#2, city#3, product#4, category#5, price#6, order_date#7, order_status#8], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=true
# +- == Final Plan ==
#    ResultQueryStage 2
#    +- ShuffleQueryStage 1
#       +- Exchange RoundRobinPartitioning(2), REPARTITION_BY_NUM, [plan_id=4547]
#          +- *(4) Project [order_id#0, customer_id#4250, customer_name#4252, city#4254, product#4256, category#4258, price#4260, order_date#4262, order_status#4264, price_with_tax#4266, price_category#4268, year(order_date#4262) AS order_year#3235, month(order_date#4262) AS order_month#3236]
#             +- *(4) Filter (isnotnull(order_status#4264) AND (order_status#4264 = Completed))
#                +- SortAggregate(key=[order_id#0], functions=[first(customer_id#1, false), first(customer_name#2, false), first(city#2806, false), first(product#2807, false), first(category#2808, false), first(price#2899, false), first(order_date#2937, false), first(order_status#2809, false), first(price_with_tax#2900, false), first(price_category#2901, false)], output=[order_id#0, customer_id#4250, customer_name#4252, city#4254, product#4256, category#4258, price#4260, order_date#4262, order_status#4264, price_with_tax#4266, price_category#4268])
#                   +- *(3) Sort [order_id#0 ASC NULLS FIRST], false, 0
#                      +- AQEShuffleRead coalesced
#                         +- ShuffleQueryStage 0
#                            +- Exchange hashpartitioning(order_id#0, 200), ENSURE_REQUIREMENTS, [plan_id=4494]
#                               +- SortAggregate(key=[order_id#0], functions=[partial_first(customer_id#1, false), partial_first(customer_name#2, false), partial_first(city#2806, false), partial_first(product#2807, false), partial_first(category#2808, false), partial_first(price#2899, false), partial_first(order_date#2937, false), partial_first(order_status#2809, false), partial_first(price_with_tax#2900, false), partial_first(price_category#2901, false)], output=[order_id#0, first#4290, valueSet#4291, first#4292, valueSet#4293, first#4294, valueSet#4295, first#4296, valueSet#4297, first#4298, valueSet#4299, first#4300, valueSet#4301, first#4302, valueSet#4303, first#4304, valueSet#4305, first#4306, valueSet#4307, first#4308, valueSet#4309])
#                                  +- *(2) Sort [order_id#0 ASC NULLS FIRST], false, 0
#                                     +- *(2) Project [order_id#0, customer_id#1, customer_name#2, city#2806, product#2807, category#2808, price#2899, pythonUDF0#4269 AS order_date#2937, order_status#2809, (cast(price#2899 as double) * 1.18) AS price_with_tax#2900, CASE WHEN (price#2899 < 30000) THEN Low WHEN ((price#2899 >= 30000) AND (price#2899 <= 50000)) THEN Medium ELSE High END AS price_category#2901]
#                                        +- BatchEvalPython [parse_date_py(order_date#7)#2936], [pythonUDF0#4269]
#                                           +- *(1) Project [order_id#0, customer_id#1, customer_name#2, city#2806, product#2807, category#2808, CASE WHEN isnull(price#2844) THEN 41277 ELSE cast(cast(price#2844 as double) as int) END AS price#2899, order_date#7, order_status#2809]
#                                              +- *(1) Project [order_id#0, customer_id#1, customer_name#2, trim(initcap(trim(initcap(city#3), None)), None) AS city#2806, trim(initcap(trim(initcap(product#4), None)), None) AS product#2807, trim(initcap(trim(initcap(category#5), None)), None) AS category#2808, CASE WHEN RLIKE(price#6, ^[0-9]+$) THEN cast(cast(price#6 as double) as int) END AS price#2844, order_date#7, trim(initcap(trim(initcap(order_status#8), None)), None) AS order_status#2809]
#                                                 +- *(1) Scan ExistingRDD[order_id#0,customer_id#1,customer_name#2,city#3,product#4,category#5,price#6,order_date#7,order_status#8]
# +- == Initial Plan ==
#    Exchange RoundRobinPartitioning(2), REPARTITION_BY_NUM, [plan_id=4461]
#    +- Project [order_id#0, customer_id#4250, customer_name#4252, city#4254, product#4256, category#4258, price#4260, order_date#4262, order_status#4264, price_with_tax#4266, price_category#4268, year(order_date#4262) AS order_year#3235, month(order_date#4262) AS order_month#3236]
#       +- Filter (isnotnull(order_status#4264) AND (order_status#4264 = Completed))
#          +- SortAggregate(key=[order_id#0], functions=[first(customer_id#1, false), first(customer_name#2, false), first(city#2806, false), first(product#2807, false), first(category#2808, false), first(price#2899, false), first(order_date#2937, false), first(order_status#2809, false), first(price_with_tax#2900, false), first(price_category#2901, false)], output=[order_id#0, customer_id#4250, customer_name#4252, city#4254, product#4256, category#4258, price#4260, order_date#4262, order_status#4264, price_with_tax#4266, price_category#4268])
#             +- Sort [order_id#0 ASC NULLS FIRST], false, 0
#                +- Exchange hashpartitioning(order_id#0, 200), ENSURE_REQUIREMENTS, [plan_id=4456]
#                   +- SortAggregate(key=[order_id#0], functions=[partial_first(customer_id#1, false), partial_first(customer_name#2, false), partial_first(city#2806, false), partial_first(product#2807, false), partial_first(category#2808, false), partial_first(price#2899, false), partial_first(order_date#2937, false), partial_first(order_status#2809, false), partial_first(price_with_tax#2900, false), partial_first(price_category#2901, false)], output=[order_id#0, first#4290, valueSet#4291, first#4292, valueSet#4293, first#4294, valueSet#4295, first#4296, valueSet#4297, first#4298, valueSet#4299, first#4300, valueSet#4301, first#4302, valueSet#4303, first#4304, valueSet#4305, first#4306, valueSet#4307, first#4308, valueSet#4309])
#                      +- Sort [order_id#0 ASC NULLS FIRST], false, 0
#                         +- Project [order_id#0, customer_id#1, customer_name#2, city#2806, product#2807, category#2808, price#2899, pythonUDF0#4269 AS order_date#2937, order_status#2809, (cast(price#2899 as double) * 1.18) AS price_with_tax#2900, CASE WHEN (price#2899 < 30000) THEN Low WHEN ((price#2899 >= 30000) AND (price#2899 <= 50000)) THEN Medium ELSE High END AS price_category#2901]
#                            +- BatchEvalPython [parse_date_py(order_date#7)#2936], [pythonUDF0#4269]
#                               +- Project [order_id#0, customer_id#1, customer_name#2, city#2806, product#2807, category#2808, CASE WHEN isnull(price#2844) THEN 41277 ELSE cast(cast(price#2844 as double) as int) END AS price#2899, order_date#7, order_status#2809]
#                                  +- Project [order_id#0, customer_id#1, customer_name#2, trim(initcap(trim(initcap(city#3), None)), None) AS city#2806, trim(initcap(trim(initcap(product#4), None)), None) AS product#2807, trim(initcap(trim(initcap(category#5), None)), None) AS category#2808, CASE WHEN RLIKE(price#6, ^[0-9]+$) THEN cast(cast(price#6 as double) as int) END AS price#2844, order_date#7, trim(initcap(trim(initcap(order_status#8), None)), None) AS order_status#2809]
#                                     +- Scan ExistingRDD[order_id#0,customer_id#1,customer_name#2,city#3,product#4,category#5,price#6,order_date#7,order_status#8]
